# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <pre>

# %% [markdown]
# # Modules

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import another as cal

a = int(input("Enter a number: "))
b = int(input("Enter a number: "))

print(cal.add(a, b))
print(cal.sub(a, b))
print(cal.multiply(a, b))
print(cal.division(a, b))
# Out:
# Enter a number:  6
# Enter a number:  7
# 13
# -1
# 42
# 0

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random as rd

temp = input("enter a string: ")

print(rd.choice(temp))
# Out:
# enter a string:  hello
# e

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
import random as rd

l1 = ["hello", "pujan", "hiii"]

print(rd.choice(l1))
# Out:
# pujan

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
print(rd.randrange(1,6))
# Out:
# 2

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random

l1 = []

while len(l1)<3:
    a = random.randint(100,999)
    if(a%5==0):
        l1.append(a)
print(l1)
# Out:
# [885, 265, 635]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
import random as rd

l1 = []
for i in range(0,100):
    l1.append(rd.randrange(100,999))

print("winner is ",rd.choice(l1))
print("runner up is ",rd.choice(l1))
# Out:
# winner is  620
# runner up is  271

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
from datetime import datetime

print(datetime.now())
# Out:
# 2025-02-21 10:49:10.835466

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
 import datetime

d1 = datetime.datetime.now()

print('Today_Date' ,d1)

d2 = d1 - datetime.timedelta(days=7)

print("befor 7days: ", d2)
# Out:
# Today_Date 2025-02-21 10:51:52.484307
# befor 7days:  2025-02-14 10:51:52.484307

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
 import datetime

d1 = datetime.datetime.now()
print('Today_Date' ,d1)

d2 = d1 + datetime.timedelta(days = random.randrange(1,7))

print("after days", d2)
print("day diffrence", d2-d1)
# Out:
# Today_Date 2025-02-21 10:53:33.812280
# after days 2025-02-25 10:53:33.812280
# day diffrence 4 days, 0:00:00

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
import datetime

d1 = datetime.datetime.now()

d2 = d1 + datetime.timedelta(days = random.randrange(1,7))

print(d2.strftime("%A"))
# Out:
# Saturday

# %% [markdown]
# ### 11) WAP to demonstrate the use of date time module.

# %%
import datetime

current_datetime = datetime.datetime.now()

print("Current Date and Time:", current_datetime)

current_date = datetime.date.today()
print("Today's Date:", current_date)

current_time = current_datetime.time()
print("Current Time:", current_time)

formatted_datetime = current_datetime.strftime("%Y-%m-%d %H:%M:%S")
print("Formatted Date and Time:", formatted_datetime)

weekday = current_date.weekday()
print("Day of the Week (0=Monday, 6=Sunday):", weekday)

month_name = current_datetime.strftime("%B")
print("Current Month Name:", month_name)

year_month = current_datetime.strftime("%Y-%m")
print("Year-Month:", year_month)
# Out:
# Current Date and Time: 2025-02-21 10:56:32.689226
# Today's Date: 2025-02-21
# Current Time: 10:56:32.689226
# Formatted Date and Time: 2025-02-21 10:56:32
# Day of the Week (0=Monday, 6=Sunday): 4
# Current Month Name: February
# Year-Month: 2025-02

# %% [markdown]
# ### 12) WAP to demonstrate the use of the math module.

# %%
import math

print("Square root of 16:", math.sqrt(16))

print("Factorial of 5:", math.factorial(5))

print("3 raised to the power of 4:", math.pow(3, 4))

print("Natural logarithm of 10:", math.log(10))

print("Value of Pi:", math.pi)
# Out:
# Square root of 16: 4.0
# Factorial of 5: 120
# 3 raised to the power of 4: 81.0
# Natural logarithm of 10: 2.302585092994046
# Value of Pi: 3.141592653589793
