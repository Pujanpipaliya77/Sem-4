# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 13</b></center>
# <pre>

# %% [markdown]
# # OOP

# %% [markdown]
# ### 01) Write a Program to create a class by name Students, and initialize attributes like name, age, and grade while creating an object.

# %%
class Students:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade

    def student(self):
        print(f"Name: {self.name}, Age: {self.age}, Grade: {self.grade}")

a = Students("Alice", 15, "10th Grade")
a.student()
# Out:
# Name: Alice, Age: 15, Grade: 10th Grade

# %% [markdown]
# ### 02) Create a class named Bank_Account with Account_No, User_Name, Email,Account_Type and Account_Balance data members. Also create a method GetAccountDetails() and DisplayAccountDetails(). Create main method to demonstrate the Bank_Account class.

# %%
class Bank_Account:
    def __init__(self, AC_No="", UserName="", Email="", Account_Type="", Balance=0.0):
        self.AC_No = AC_No
        self.UserName = UserName
        self.Email = Email
        self.Account_Type = Account_Type
        self.Balance = Balance

    def GetAccountDetails(self):
        self.AC_No = input("Enter Account Number: ")
        self.UserName = input("Enter your Name: ")
        self.Email = input("Enter your Email: ")
        self.Account_Type = input("Enter Account type: ")
        self.Balance = float(input("Enter current Balance: "))

    def DisplayAccountDetails(self):
        print(f"""
        Account Number: {self.AC_No}
        UserName: {self.UserName}
        Email: {self.Email}
        Account Type: {self.Account_Type}
        Balance: {self.Balance}
        """)

def main():
    Account = Bank_Account()
    Account.GetAccountDetails()
    Account.DisplayAccountDetails()

if __name__ == "__main__":
    main()
# Out:
# Enter Account Number:  23010101426
# Enter your Name:  pujan
# Enter your Email:  pujan@gmail.com
# Enter Account type:  saving
# Enter current Balance:  2300000
#         Account Number: 23010101426
#         UserName: pujan
#         Email: pujan@gmail.com
#         Account Type: saving
#         Balance: 2300000.0

# %% [markdown]
# ### 03) WAP to create Circle class with area and perimeter function to find area and perimeter of circle.

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

r = float(input("Enter the radius: "))
c = Circle(r)
print("Area:", c.area())
print("Perimeter:", c.perimeter())
# Out:
# Enter the radius:  5
# Area: 78.53981633974483
# Perimeter: 31.41592653589793

# %% [markdown]
# ### 04) Create a class for employees that includes attributes such as name, age, salary, and methods to update and display employee information.

# %%
class Employee:
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary

    def update_employee(self, name=None, age=None, salary=None):
        if name is not None:
            self.name = name
        if age is not None:
            self.age = age
        if salary is not None:
            self.salary = salary

    def display_employee(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Salary: {self.salary}")

if __name__ == "__main__":
    emp = Employee("pujan", 28, 60000)
    print("Employee details:")
    emp.display_employee()
    
    print("\nUpdating employee details...")
    emp.update_employee(age=29, salary=65000)
    print("Updated employee details:")
    emp.display_employee()
# Out:
# Employee details:
# Name: pujan
# Age: 28
# Salary: 60000
#
# Updating employee details...
# Updated employee details:
# Name: pujan
# Age: 29
# Salary: 65000

# %% [markdown]
# ### 05) Create a bank account class with methods to deposit, withdraw, and check balance.

# %%
class Employee:
    def __init__(self, account_no, user_name, balance):
        self.account_no = account_no
        self.user_name = user_name
        self.balance = balance  

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposit {amount:.2f}. New balance: {self.balance:.2f}")
        else:
            print("Invalid deposit amount!!")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdraw {amount:.2f}. Remaining balance: {self.balance:.2f}")
        else:
            print("Invalid withdrawal amount or insufficient funds!!")

    def check_balance(self):
        print(f"Current balance: {self.balance:.2f}")

emp = Employee(12345, "JohnDoe", 1000.00)
emp.deposit(500)
emp.withdraw(200)
emp.check_balance()
# Out:
# Deposit 500.00. New balance: 1500.00
# Withdraw 200.00. Remaining balance: 1300.00
# Current balance: 1300.00

# %% [markdown]
# ### 06) Create a class for managing inventory that includes attributes such as item name, price, quantity, and methods to add, remove, and update items.

# %%
class InventoryManager:
    def __init__(self):
        self.items = {}

    def add_item(self, name, price, quantity):
        if name in self.items:
            self.items[name]['quantity'] += quantity
        else:
            self.items[name] = {'price': price, 'quantity': quantity}

    def remove_item(self, name, quantity):
        if name in self.items:
            if self.items[name]['quantity'] > quantity:
                self.items[name]['quantity'] -= quantity
            else:
                del self.items[name]

    def update_price(self, name, price):
        if name in self.items:
            self.items[name]['price'] = price

    def display_inventory(self):
        for name, details in self.items.items():
            print(f"{name}: ${details['price']}, Quantity: {details['quantity']}")

if __name__ == "__main__":
    inventory = InventoryManager()
    inventory.add_item("Laptop", 1200, 10)
    inventory.add_item("Mouse", 25, 50)
    inventory.display_inventory()
    inventory.update_price("Laptop", 1100)
    inventory.remove_item("Mouse", 20)
    inventory.display_inventory()
# Out:
# Laptop: $1200, Quantity: 10
# Mouse: $25, Quantity: 50
# Laptop: $1100, Quantity: 10
# Mouse: $25, Quantity: 30

# %% [markdown]
# ### 07) Create a Class with instance attributes of your choice.

# %%
class Product:
    def __init__(self, name, category, price, stock):
        self.name = name
        self.category = category
        self.price = price
        self.stock = stock

    def update_stock(self, quantity):
        self.stock += quantity

    def apply_discount(self, discount):
        self.price -= self.price * (discount / 100)

    def display_info(self):
        print(f"Product: {self.name}, Category: {self.category}, Price: ${self.price:.2f}, Stock: {self.stock}")

if __name__ == "__main__":
    product = Product("Smartphone", "Electronics", 699, 50)
    product.display_info()
    product.apply_discount(10)
    product.update_stock(20)
    product.display_info()
# Out:
# Product: Smartphone, Category: Electronics, Price: $699.00, Stock: 50
# Product: Smartphone, Category: Electronics, Price: $629.10, Stock: 70

# %% [markdown]
# ### 08) Create one class student_kit
# #### Within the student_kit class create one class attribute principal name ( Mr ABC )
# #### Create one attendance method and take input as number of days.
# #### While creating student take input their name .
# #### Create one certificate for each student by taking input of number of days present in class.

# %% [markdown]
# ### 09) Define Time class with hour and minute as data member. Also define addition method to add two time objects.
