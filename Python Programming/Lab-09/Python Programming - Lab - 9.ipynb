# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 9</b></center>
# <pre>

# %% [markdown]
# # File I/O

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
fp = open("abc.txt","r")
print(fp.read())

fp = open("abc.txt","r")
for i in fp:
    print(i.strip())

fp = open("abc.txt","r")
print(fp.readlines())
# Out:
# hellooo hiiii
# helllo my name is pujan
# hellooo hiiii
# helllo my name is pujan
# hellooo hiiii
# helllo my name is pujan
# hellooo hiiii
# helllo my name is pujan
# hellooo hiiii
# helllo my name is pujan
# hellooo hiiii
# helllo my name is pujan
# ['hellooo hiiii\n', 'helllo my name is pujan\n', 'hellooo hiiii\n', 'helllo my name is pujan\n', 'hellooo hiiii\n', 'helllo my name is pujan']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
fp = open("new.txt","x")
fp.write("hellooo")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 fp = open("new.txt","x")
#       2 fp.write("hellooo")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'new.txt'

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
fp = open("abc.txt","r")
for i in range(5):
    print(fp.readline())
# Out:
# hellooo hiiii
#
# helllo my name is pujan
#
# hellooo hiiii
#
# helllo my name is pujan
#
# hellooo hiiii

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file

# %%
fp = open("abc.txt","r")
words = fp.read().split()
max_len = max(len(i) for i in words)
ans = [i for i in words if len(i) == max_len]
ans
# Out:
# ['hellooo', 'hellooo', 'hellooo']

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
fp = open("abc.txt","r")
l = 0
w = 0
c = 0
for i in fp:
    l += 1
    w += len(i.split())
    c += len(i.strip().replace(" ",""))

print(l)
print(w)
print(c)
# Out:
# 6
# 21
# 93

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
fp = open("other.txt","r")
first_file=print(fp.read())

fp = open("second.txt","w")
fp.write("first_file")
# Out:
# 1230
# 4560
# 7890
# 10

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
fp = open("other.txt","r")
fp.seek(0,2)
print(fp.tell())
# Out:
# 15

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
fp = open("xyz.txt","r")
words = fp.read().split()
def occurence(words):
    str = input("enter a string: ")
    x=words.count(str)
    return x
print(occurence(words))
# Out:
# enter strinmh: abc
# 2

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
fp = open("second.txt","w+")
for i in range (1,6):
    mark = input("enter marks of subject: ")
    fp.write(mark + '\n')
    
fp.seek(0)
li = [int(mark.strip()) for mark in fp.readlines()]
print(f"the highest score is:  {max(li)}")
fp.close()
# Out:
# enter marks of subject {i} : 10
# enter marks of subject {i} : 20
# enter marks of subject {i} : 30
# enter marks of subject {i} : 40
# enter marks of subject {i} : 50
# the highest score is:  50

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
def is_prime(num):
    if num>r

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
fp = open("other.txt","r")
x = fp.read()

fp = open("second.txt","r")
y = fp.read()

fp = open("third.txt","w+")
fp.write(x)
fp.write(y)
fp.close()

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.
